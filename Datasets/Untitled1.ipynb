# %%
from kivymd.app import MDApp
from kivy.lang import Builder

kv = """
Screen:
    BoxLayout:
        orientation: 'vertical'
        MDToolbar:
            title: "MDToolbar"
            left_action_items: [["menu", lambda x: nav_draw.set_state()]]
        Widget:
                    
    MDNavigationDrawer:
        id: nav_draw
        orientation: "vertical"
        padding: "8dp"
        spacing: "8dp"
        
        AnchorLayout:
            anchor_x: "left"
            size_hint_y: None
            height: avatar.height
            Image:
                id: avatar
                size_hint: None, None
                size: "56dp", "56dp"
                source: "data/logo/kivy-icon-256.png"
        MDLabel:
            text: "Kaustubh Gupta"
            font_style: "Button"
            size_hint_y: None
            height: self.texture_size[1]
    
        MDLabel:
            text: "youreamil@gmail.com"
            font_style: "Caption"
            size_hint_y: None
            height: self.texture_size[1]
        
        ScrollView:
            MDList:
                OneLineAvatarListItem:
                    on_press:
                        nav_draw.set_state("close")
                    text: "Home"
                    IconLeftWidget:
                        icon: "home"
                OneLineAvatarListItem:
                    on_press:
                        nav_draw.set_state("close")
                    text: "About"
                    IconLeftWidget:
                        icon: 'information'
                            
        Widget:
"""

class Main(MDApp):
    def build(self):
        return Builder.load_string(kv)


Main().run()
# Out:
# [WARNING] [Config      ] Older configuration version detected (0 instead of 24)
# [WARNING] [Config      ] Upgrading configuration in progress.
# [INFO   ] [Logger      ] Record log in /home/nexia/.kivy/logs/kivy_22-09-14_0.txt
# [INFO   ] [Kivy        ] v2.1.0
# [INFO   ] [Kivy        ] Installed at "/home/nexia/miniconda3/envs/kivy/lib/python3.10/site-packages/kivy/__init__.py"
# [INFO   ] [Python      ] v3.10.4 (main, Mar 31 2022, 08:41:55) [GCC 7.5.0]
# [INFO   ] [Python      ] Interpreter at "/home/nexia/miniconda3/envs/kivy/bin/python"
# [INFO   ] [Logger      ] Purge log fired. Processing...
# [INFO   ] [Logger      ] Purge finished!
# [INFO   ] [KivyMD      ] 1.0.2, git-38fe356, 2022-08-11 (installed at "/home/nexia/miniconda3/envs/kivy/lib/python3.10/site-packages/kivymd/__init__.py")
# [INFO   ] [Factory     ] 189 symbols loaded
# [INFO   ] [Image       ] Providers: img_tex, img_dds, img_sdl2, img_pil (img_ffpyplayer ignored)
# [INFO   ] [Text        ] Provider: sdl2
# [INFO   ] [Window      ] Provider: sdl2
# [INFO   ] [GL          ] Using the "OpenGL" graphics system
# [INFO   ] [GL          ] Backend used <sdl2>
# [INFO   ] [GL          ] OpenGL version <b'4.6 (Compatibility Profile) Mesa 21.2.6'>
# [INFO   ] [GL          ] OpenGL vendor <b'AMD'>
# [INFO   ] [GL          ] OpenGL renderer <b'AMD RENOIR (DRM 3.42.0, 5.14.21-051421-generic, LLVM 12.0.0)'>
# [INFO   ] [GL          ] OpenGL parsed version: 4, 6
# [INFO   ] [GL          ] Shading version <b'4.60'>
# [INFO   ] [GL          ] Texture max size <16384>
# [INFO   ] [GL          ] Texture max units <32>
# [INFO   ] [Window      ] auto add sdl2 input provider
# [INFO   ] [Window      ] virtual keyboard not allowed, single mode, not docked
# [INFO   ] [GL          ] NPOT texture support is available
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [1], in <cell line: 64>()
#      60     def build(self):
#      61         return Builder.load_string(kv)
# ---> 64 Main().run()
#
# File ~/miniconda3/envs/kivy/lib/python3.10/site-packages/kivy/app.py:954, in App.run(self)
#     951 def run(self):
#     952     '''Launches the app in standalone mode.
#     953     '''
# --> 954     self._run_prepare()
#     955     runTouchApp()
#     956     self.stop()
#
# File ~/miniconda3/envs/kivy/lib/python3.10/site-packages/kivy/app.py:923, in App._run_prepare(self)
#     921 if not self.built:
#     922     self.load_config()
# --> 923     self.load_kv(filename=self.kv_file)
#     924     root = self.build()
#     925     if root:
#
# File ~/miniconda3/envs/kivy/lib/python3.10/site-packages/kivy/app.py:676, in App.load_kv(self, filename)
#     674 else:
#     675     try:
# --> 676         default_kv_directory = dirname(getfile(self.__class__))
#     677         if default_kv_directory == '':
#     678             default_kv_directory = '.'
#
# File ~/miniconda3/envs/kivy/lib/python3.10/inspect.py:785, in getfile(object)
#     783             return module.__file__
#     784         if object.__module__ == '__main__':
# --> 785             raise OSError('source code not available')
#     786     raise TypeError('{!r} is a built-in class'.format(object))
#     787 if ismethod(object):
#
# OSError: source code not available
