# %%
import pandas as pd
from matplotlib import rc
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
rc('text', usetex=True)
from matplotlib import pyplot as plt
import matplotlib
import numpy as np
matplotlib.rcParams['axes.unicode_minus'] = False
pd.options.display.max_rows = 999

# %%
maier_data = pd.read_excel('RBC and asexual Pf lipidome.xlsx',
                               header=1, index_col=0)

# %%
pgf_with_latex = {
    "pgf.texsystem": "xelatex",     # Use xetex for processing
    "text.usetex": True,            # use LaTeX to write all text
    "font.family": "serif",         # use serif rather than sans-serif
    "font.serif": "Ubuntu",
    "font.sans-serif": [],          # Unset sans-serif
    "font.monospace": "Ubuntu Mono",
    "axes.labelsize": 10,
    "font.size": 10,
    "legend.fontsize": 8,
    "axes.titlesize": 14,           # Title size when one figure
    "xtick.labelsize": 8,
    "ytick.labelsize": 8,
    "figure.titlesize": 12,         # Overall figure title
    "pgf.rcfonts": False,           # Ignore Matplotlibrc
    "text.latex.unicode": True,
    "pgf.preamble": [
        r'\usepackage{xcolor}',     # xcolor for colours
        r'\usepackage{fontspec}',
        r'\setmainfont{Ubuntu}',
        r'\setmonofont{Ubuntu Mono}',
        r'\usepackage{unicode-math}',
        r'\setmathfont{Ubuntu}'
    ]
}
matplotlib.rcParams.update(pgf_with_latex)
# Out:
# /home/maxim/anaconda3/envs/tellur/lib/python3.6/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The text.latex.unicode rcparam was deprecated in Matplotlib 3.0 and will be removed in 3.2.
#   self[key] = other[key]

# %%
t = np.linspace(0.0, 1.0, 100)
s = np.cos(4 * np.pi * t) + 2

fig, ax = plt.subplots(figsize=(6, 4), tight_layout=True)
ax.plot(t, s)
text1=[r'\bf{phase field} $\phi$'+r'\bf{phase field} $\phi$', {'color': '#ff4d4d', 'fontsize': 20}]
ax.set_xlabel(text1[0],text1[1])

ax.set_ylabel('\\textit{Velocity (\N{DEGREE SIGN}/sec)}', fontsize=16)
ax.set_title(r'\TeX\ is Number $\displaystyle\sum_{n=1}^\infty'
             r'\frac{-e^{i\pi}}{2^n}$!', fontsize=16, color='r')

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.offsetbox as of

#plt.style.use('fivethirtyeight')

# Set-up in a similar way to the LaTeX example
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = 'Ubuntu'
plt.rcParams['font.sans-serif'] = []
plt.rcParams['font.monospace'] = 'Ubuntu Mono'
plt.rcParams['axes.labelsize'] = 10
plt.rcParams['font.size'] = 10
plt.rcParams['legend.fontsize'] = 8
plt.rcParams['axes.titlesize'] = 14
plt.rcParams['xtick.labelsize'] = 8
plt.rcParams['ytick.labelsize'] = 8
plt.rcParams['figure.titlesize'] = 12

fig = plt.figure(figsize=(8, 6), dpi=400)
plt.bar([1, 2, 3, 4], [125, 100, 90, 110], label="Product A",
        width=0.5, align='center')
ax1 = plt.gca()

# Split each line of text into a list of strings and formats
cmt_line1_txt = ["Our '", "Green Shoots", "' Marketing campaign, started in ",]
cmt_line1_fmt = [{'ha': 'left', 'va': 'bottom'},
            {'color':'#0BFF01', 'weight':'bold', 'ha':'left', 'va':'bottom'},
            {'color':'black', 'ha':'left', 'va':'bottom'},
            ]
cmt_line2_txt = ["Q3 ", "showed some positive impact in ",
            "Q4", ". Further ", "positive ",
            ]
cmt_line2_fmt = [
    {'color':'#BBBBBB', 'ha':'left', 'va':'bottom'},
    {'color':'black', 'ha':'left', 'va':'bottom'},
    {'color':'#BBBBBB', 'ha':'left', 'va':'bottom'},
    {'color':'black', 'ha':'left', 'va':'bottom'},
    {'color':'#011EFE', 'fontweight': 'bold', 'ha':'left', 'va':'bottom'},
]

cmt_line3_txt = ["impact", " is expected in ", "later quarters."]
cmt_line3_fmt=[
{'color':'blue', 'fontweight': 'bold', 'ha':'left', 'va':'bottom'},
{'color':'black', 'ha':'left', 'va':'bottom'},
{'style': 'italic', 'ha':'left', 'va':'bottom'}
]

# Create a single list for each line of text and format
# The list for each line is a number of TextArea objects
cmt_line1_lst = []
for txt, frmt in zip(cmt_line1_txt, cmt_line1_fmt):
    print(txt+str(frmt))
    cmt_line1_lst.append(of.TextArea(txt, textprops=dict(frmt)))
print(cmt_line1_lst)
cmt_line2_lst = []
for txt, frmt in zip(cmt_line2_txt, cmt_line2_fmt):
    cmt_line2_lst.append(of.TextArea(txt, textprops=dict(frmt)))

cmt_line3_lst = []
for txt, frmt in zip(cmt_line3_txt, cmt_line3_fmt):
    cmt_line3_lst.append(of.TextArea(txt, textprops=dict(frmt)))

# Pack each Text object in a line into a Horizontal Packer
texts_hbox1 = of.HPacker(children=cmt_line1_lst, pad=0, sep=0)
texts_hbox2 = of.HPacker(children=cmt_line2_lst, pad=0, sep=0)
texts_hbox3 = of.HPacker(children=cmt_line3_lst, pad=0, sep=0)

# Put the Horizontally Packed lines into a list
texts_line_store = []
texts_line_store.append(texts_hbox1)
texts_line_store.append(texts_hbox2)
texts_line_store.append(texts_hbox3)

# Put the lines of text into a Vertical Box to get the final result
texts_vbox = of.VPacker(children=texts_line_store, pad=2, sep=0)

# Put the final box on the figure
annot2_bbox=dict(facecolor='yellow', boxstyle='round', edgecolor='0.5', alpha=1)
arrow2=dict(arrowstyle='-|>, head_width=0.3', linewidth=1, facecolor='black')
annot2 = of.AnnotationBbox(texts_vbox, xy=(4, 80),xybox=(2.50, 120),
                        xycoords='data', boxcoords='data',
                        arrowprops=arrow2, bboxprops=annot2_bbox)
ax1.add_artist(annot2)

# Standard description of the plot
# Set xticks, Font is set globally
plt.xticks([1, 2, 3, 4], ['Q1', 'Q2', 'Q3', 'Q4'])
plt.xlabel('Time - FY quarters')
plt.ylabel('Sales - unadjusted')
plt.title('Total sales by quarter')
plt.legend(loc='best')
# Out:
# Our '{'ha': 'left', 'va': 'bottom'}
# Green Shoots{'color': '#0BFF01', 'weight': 'bold', 'ha': 'left', 'va': 'bottom'}
# ' Marketing campaign, started in {'color': 'black', 'ha': 'left', 'va': 'bottom'}
# [<matplotlib.offsetbox.TextArea object at 0x7f9d87191e80>, <matplotlib.offsetbox.TextArea object at 0x7f9d8719bc18>, <matplotlib.offsetbox.TextArea object at 0x7f9d8719bcf8>]

# CE                       54.980000   98.610000   54.210000
# DG                       11.720000    0.000000   20.120000
# FC                      259.350000  284.380000  354.460000
# PC                      107.290000  117.190000  175.310000
# PE                       33.320000   28.550000   71.520000
# PG                        0.000000    0.000000    0.000000
# PS                       21.380000   22.310000   33.000000
# TG                        0.000000    0.000000   25.550000
# NaN                            NaN         NaN         NaN
# Neutral lipids           66.700000   98.610000   99.880000
# Phospholipids           161.990000  168.050000  279.830000
# Free cholesterol        259.350000  284.380000  354.460000
# Sphingolipids           129.580000  119.730000  198.550000
# NaN                            NaN         NaN         NaN
# total                   617.620000  670.770000  932.720000
# NaN                            NaN         NaN         NaN
# % Neutral lipids         10.799521   14.701015   10.708466
# % Phospholipids          26.228101   25.053297   30.001501
# % Free cholesterol       41.991840   42.396052   38.002830
# % Sphingolipids          20.980538   17.849635   21.287203
# NaN                            NaN         NaN         NaN
# Phospholipids (total)   161.990000  168.050000  279.830000
# % PC                     66.232483   69.735198   62.648751
# % PE                     20.569171   16.988991   25.558375
# % PG                      0.000000    0.000000    0.000000
# % PS                     13.198346   13.275811   11.792874
# NaN                            NaN         NaN         NaN
# Neutral lipids (total)   66.700000   98.610000   99.880000
# % CE                     82.428786  100.000000   54.275130
# % DAG                    17.571214    0.000000   20.144173
# % TAG                     0.000000    0.000000   25.580697
# NaN                            NaN         NaN         NaN
# Sphingolipids (total)   129.580000  119.730000  198.550000
# % Cer                     3.171786    2.096384    2.674389
# % DHSM                    0.779441    0.977199    1.062705
# % SM                     96.048773   96.926418   96.262906

# %%
rbc_ave = maier_data.iloc[:,0:3].mean(axis=1)

# %%
lists = maier_data.iloc[:,0:3].std(axis=1).index.to_list()

maier_data.index = [str(item).replace('%','\% ').replace('_','-') for item in lists]
maier_data
# Out:
#                               RBC1        RBC2        RBC3      Ring 1  \
# CE 16:0                   7.580000    8.470000    7.040000    3.940000
# CE 16:1                   2.300000    4.900000    2.110000    0.000000
# CE 18:1                   9.940000   14.400000    8.710000    3.570000
# CE 18:2                  27.430000   53.540000   27.970000   11.400000
# CE 18:3                   3.980000    8.980000    4.140000    1.040000
# CE 20:4                   3.750000    8.320000    3.030000    1.740000
# CE 20:5                   0.000000    0.000000    1.210000    0.000000
# DAG (32:0) 16:0-16:0      0.000000    0.000000    0.000000    0.000000
# DAG (34:0) 16:0-18:0      0.000000    0.000000    0.000000    0.000000
# DAG (34:1) 16:0-18:1      0.000000    0.000000    0.000000    0.000000
# DAG (36:1) 18:0-18:1      0.000000    0.000000    0.000000    0.000000
# DAG (36:2) 18:1-18:1     11.720000    0.000000   20.120000   20.440000
# FreeChol                259.350000  284.380000  354.460000  253.640000
# LPC 16:0                  0.000000    6.020000    4.540000    2.750000
# LPC 18:0                  0.000000    4.320000    0.000000    0.000000
# PC 32:0                   3.900000    4.220000    6.900000   15.540000
# PC 32:1                   0.000000    1.300000    1.940000    1.870000
# PC 34:0                   0.000000    0.000000    1.650000    4.170000
# PC 34:1                  31.120000   25.270000   39.520000   77.900000
# PC 34:2                  22.550000   25.780000   35.530000   28.850000
# PC 34:3                   0.000000    0.000000    0.000000    2.500000
# PE                         456.110000   591.780000   976.120000   388.280000
# PG                          42.130000    99.670000   154.560000    49.260000
# PS                         124.220000   127.540000   201.120000    70.460000
# TG                          10.290000   258.420000   221.420000    70.140000
# nan                               NaN          NaN          NaN          NaN
# Neutral lipids             272.420000   591.440000   686.310000   308.060000
# Phospholipids             1494.560000  2330.660000  3780.200000  1676.420000
# Free cholesterol           406.900000   337.010000   516.470000   453.880000
# Sphingolipids              162.780000   136.350000   150.800000   139.020000
# nan                               NaN          NaN          NaN          NaN
# total                     2336.660000  3395.460000  5133.780000  2577.380000
# nan                               NaN          NaN          NaN          NaN
# \%  Neutral lipids          11.658521    17.418553    13.368512    11.952448
# \%  Phospholipids           63.961381    68.640479    73.633853    65.043571
# \%  Free cholesterol        17.413744     9.925312    10.060229    17.610131
# \%  Sphingolipids            6.966354     4.015656     2.937407     5.393850
# nan                               NaN          NaN          NaN          NaN
# Phospholipids (total)     1494.560000  2330.660000  3780.200000  1676.420000
# \%  PC                      58.351622    64.860168    64.769060    69.697331
# \%  PE                      30.518012    25.391091    25.821914    23.161260
# \%  PG                       2.818890     4.276471     4.088673     2.938404
# \%  PS                       8.311476     5.472270     5.320353     4.203004
# nan                               NaN          NaN          NaN          NaN
# Neutral lipids (total)     272.420000   591.440000   686.310000   308.060000
# \%  CE                      37.772557     0.596848     0.660052     2.090502
# \%  DAG                     58.450187    55.709793    67.077560    75.141206
# \%  TAG                      3.777256    43.693359    32.262389    22.768292
# nan                               NaN          NaN          NaN          NaN
# Sphingolipids (total)      162.780000   136.350000   150.800000   139.020000
# \%  Cer                      3.237498     4.129080     3.972149     3.524673
# \%  DHSM                     1.806119     2.097543     3.534483     2.589555
# \%  SM                      94.956383    93.773377    92.493369    93.885772

# %%
#[str(item).replace('%','\% ').replace('_','-') for item in lists]

# %%
maier_data.columns[0:3].to_list()
t = maier_data.iloc[:,0:3].dropna().T
t
# Out:
#       CE 16:0  CE 16:1  CE 18:1  CE 18:2  CE 18:3  CE 20:4  CE 20:5  \
# RBC1     7.58     2.30     9.94    27.43     3.98     3.75     0.00
# RBC2     8.47     4.90    14.40    53.54     8.98     8.32     0.00
# RBC3     7.04     2.11     8.71    27.97     4.14     3.03     1.21
#
#       DAG (32:0) 16:0-16:0  DAG (34:0) 16:0-18:0  DAG (34:1) 16:0-18:1  ...  \
# RBC1                   0.0                   0.0                   0.0  ...
# RBC2                   0.0                   0.0                   0.0  ...
# RBC3                   0.0                   0.0                   0.0  ...
#
#       \%  PG     \%  PS  Neutral lipids (total)      \%  CE    \%  DAG  \
# RBC1     0.0  13.198346                   66.70   82.428786  17.571214
# RBC2     0.0  13.275811                   98.61  100.000000   0.000000
# RBC3     0.0  11.792874                   99.88   54.275130  20.144173
#
#         \%  TAG  Sphingolipids (total)   \%  Cer  \%  DHSM     \%  SM
# RBC1   0.000000                 129.58  3.171786  0.779441  96.048773
# RBC2   0.000000                 119.73  2.096384  0.977199  96.926418
# RBC3  25.580697                 198.55  2.674389  1.062705  96.262906
#
# [3 rows x 151 columns]

# %%
t1=t.iloc[:,0:129]
t1.mean().plot(kind='pie')

# %%
t3=t.iloc[:,129:133]
t3.mean().plot(kind='pie')

# %%
names = t3.columns.to_list()
names
# Out:
# ['Neutral lipids', 'Phospholipids', 'Free cholesterol', 'Sphingolipids']

# %%
t3.mean().values
# Out:
# array([ 88.39666667, 203.29      , 299.39666667, 149.28666667])

# %%
def index_containing_substring(the_list, substring):
    for i, s in enumerate(the_list):
        if substring in s:
              return i
    return -1

# %%
from itertools import chain 
import itertools as it

t2 = t.iloc[:,133:151]
col_total = [list(g) for k, g in it.groupby(t2.columns, lambda x: 'total' in x) if k]
col_total_k=np.array(col_total).flatten()
col_vals = [list(g) for k, g in it.groupby(t2.columns, lambda x: 'total' in x) if not k]
col_vals_fl=list(chain.from_iterable(col_vals))

labels_lips1=[]
plots=[]
for i,name in enumerate(names):
    index = index_containing_substring(col_total_k, name)
    
    if index != -1:
        es = col_total[index]
        df = t2[es + col_vals[index]]
        df = df.mean().T.sort_values(ascending=False).T
        
        labels_lips1.append(df.index[1:].to_list())
        values = df[1:]*t3.mean().values[i]/100
        print(df[col_vals[index]])
        plots.append(values)
    else:
        print(name)
        plots.append([t3.mean().values[i]])
        labels_lips1.append(['\% '+name])
        
flatten_list = list(chain.from_iterable(plots))
print(flatten_list)
labels_lips = list(chain.from_iterable(labels_lips1))
labels_lips1
# Out:
# \%  CE      1.115801
# \%  DAG    65.976186
# \%  TAG    32.908013
# dtype: float64
# \%  PC    66.442186
# \%  PE    24.791422
# \%  PG     3.767849
# \%  PS     4.998542
# dtype: float64
# Free cholesterol
# \%  Cer      3.875300
# \%  DHSM     2.740527
# \%  SM      93.384173
# dtype: float64
# [348.75232018066737, 173.95285398672868, 5.898159165937276, 1724.6796996014411, 643.5258107297992, 129.75016332355833, 97.80432634520166, 435.78666666666663, 132.65844282266443, 5.505122393847548, 3.8931014501546537]
# [['\\%  DAG', '\\%  TAG', '\\%  CE'],
#  ['\\%  PC', '\\%  PE', '\\%  PS', '\\%  PG'],
#  ['\\% Free cholesterol'],
#  ['\\%  SM', '\\%  Cer', '\\%  DHSM']]

# %%
size = 0.1
r=2
# Data to plot
labels = t3.columns.to_list()
sizes = t3.mean().values
labels_gender = labels_lips
sizes_gender = flatten_list
colors = ['#e60000', '#e67300', '#00cc00', '#005ce6']
colors_gender = ['#ff4d4d','#ff3333', '#ff1a1a', '#ffbf80','#ffb366', '#ffa64d','#ff9933','#99ff99','#3399ff','#1a8cff','#0080ff']
# Plot
fig, ax =  plt.subplots(figsize=(10, 10), subplot_kw=dict(aspect="equal"))



plt.pie(sizes_gender,colors = colors_gender, startangle=0, radius=r, shadow=True,
        textprops={'size': 16})

wedges, texts = ax.pie( np.array(sizes),  colors = colors, radius=r*0.7, startangle=0, shadow=True)

#plt.pie(np.array(sizes), colors = 'black', radius=r*0.6, startangle=0)

bbox_props = dict(boxstyle="round", fc="w", ec="k", lw=0.2, alpha=1)

kw = dict(arrowprops=dict(arrowstyle="-",
                            color="0",
                            patchB=None,
                            shrinkB=0),
          bbox=bbox_props, zorder=1, va="center")
it = 0
for i, p in enumerate(wedges):
    
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=1,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    #kw['bbox']['fc']='#ffffe6'
    
    texts_line_store = []
    
    for ind,nme in enumerate([labels[i]]+labels_lips1[i]):
        if ind == 0:
            percent = sizes[i]/sizes.sum()*100
            txt = str(nme)+' '+ str(np.round(percent,2))+'\%' 
            frmt = {'color':colors[i], 'fontweight': 'bold', 'ha':'left', 'va':'bottom','fontsize':29}
            cmt_line3_lst = [of.TextArea(txt, textprops=dict(frmt))]
            
            texts_hbox3 = of.HPacker(children=cmt_line3_lst, pad=0, sep=0)
            
            texts_line_store.append(texts_hbox3)
        else:
            percent = np.array(plots[i][ind-1])/np.array(plots[i]).sum()*100
            txt = str(np.round(percent,2))+str(nme)
            frmt = {'color':colors_gender[it], 'fontweight': 'bold', 'ha':'left', 'va':'bottom', 'fontsize':25}
            it+=1
            cmt_line3_lst = [of.TextArea(txt, textprops=dict(frmt))]
            
            texts_hbox3 = of.HPacker(children=cmt_line3_lst, pad=0, sep=0)
            
            texts_line_store.append(texts_hbox3)
        
        texts_vbox = of.VPacker(children=texts_line_store, pad=2, sep=0)
        
        # Put the final box on the figure
        #annot2_bbox=dict(facecolor='yellow', boxstyle='round', edgecolor='0.5', alpha=1)
        #arrow2=dict(arrowstyle='-|>, head_width=0.3', linewidth=1, facecolor='black')
        
        annot2 = of.AnnotationBbox(texts_vbox, xy=(np.sign(x), y),xybox=(np.sign(x), y),
                                xycoords='data', boxcoords=('data'),
                                arrowprops=kw["arrowprops"], bboxprops=bbox_props)
        

        ax.add_artist(annot2)
        #s = ax.annotate(text, color= colors[i], xy=(x, y), xytext=(1.8*r*np.sign(x), 1.6*r*y),size = 20,
                   # horizontalalignment=horizontalalignment, **kw)
        
#centre_circle = plt.Circle((0,0),1.24,color='white', fc='white',linewidth=2)
#fig.gca().add_artist(centre_circle)
print(it)
plt.show()
# save
from io import BytesIO
f = BytesIO()
plt.savefig(f, format="svg")
# Out:
# 11

# %%
phase = ['uRBC', 'Ring', 'Trophozoite', 'Schizont']
import itertools as it

for x in range(0,4):
    p = x*3
    fig, ax1  = plt.subplots(figsize=(8.8, 5.51))
    data = maier_data.iloc[:,p:p+3]
    n_phase = x
    t = data.dropna().T
    t3 = t.iloc[:,129:133]
    t3.mean().plot(kind='pie')
    ax1.set_title(phase[n_phase], fontsize=16)
    ax1.set_ylabel('')
    
    t2 = t.iloc[:,133:151]
    col_total = [list(g) for k, g in it.groupby(t2.columns, lambda x: 'total' in x) if k]
    col_vals = [list(g) for k, g in it.groupby(t2.columns, lambda x: 'total' in x) if not k]
    
    for i,es in enumerate(col_total):
        df = t2[es + col_vals[i]]
        fig2, ax2  = plt.subplots(figsize=(8.8, 5.51))
        box1 = ax2.boxplot(df[es].values, positions=[0], labels = es)
        ax2.set_ylabel(es[0] + ' in umol')
        ax3 = ax2.twinx()
        box2 = ax3.boxplot(df[col_vals[i]].values,
                         positions=list(range(1,len(col_vals[i])+1)),
                         labels = col_vals[i])
        ax3.set_ylabel('\% of ' + es[0])
    
    names = t3.columns.to_list()
    from itertools import chain 
    
    col_total_k=np.array(col_total).flatten()
    col_vals_fl=list(chain.from_iterable(col_vals))
    
    labels_lips1=[]
    plots=[]
    for i,name in enumerate(names):
        index = index_containing_substring(col_total_k, name)

        if index != -1:
            es = col_total[index]
            df = t2[es + col_vals[index]]
            df = df.mean().T.sort_values(ascending=False).T

            labels_lips1.append(df.index[1:].to_list())
            values = df[1:]*t3.mean().values[i]/100
            print(df[col_vals[index]])
            plots.append(values)
        else:
            print(name)
            plots.append([t3.mean().values[i]])
            labels_lips1.append(['\% '+name])
    flatten_list = list(chain.from_iterable(plots))
    labels_lips = list(chain.from_iterable(labels_lips1))
    
    size = 0.1
    r=2
    # Data to plot
    labels = t3.columns.to_list()
    sizes = t3.mean().values
    labels_gender = labels_lips
    sizes_gender = flatten_list
    colors = ['#e60000', '#e67300', '#00cc00', '#005ce6']
    colors_gender = ['#ff4d4d','#ff3333', '#ff1a1a', '#ffbf80','#ffb366', '#ffa64d','#ff9933','#00b300','#3399ff','#1a8cff','#0080ff']
    # Plot import itertools as it
    fig, ax =  plt.subplots(figsize=(10, 10), subplot_kw=dict(aspect="equal"))


    plt.pie(sizes_gender,colors = colors_gender, startangle=0, radius=r, shadow=True,
            textprops={'size': 16})

    wedges, texts = ax.pie( np.array(sizes),  colors = colors, radius=r*0.7, startangle=0, shadow=True)
    ax.set_title(phase[n_phase], fontsize=30,color='w',fontweight = 'bold')
    #plt.pie(np.array(sizes), colors = 'black', radius=r*0.6, startangle=0)

    bbox_props = dict(boxstyle="round", fc="w", ec="k", lw=0.2, alpha=1)

    kw = dict(arrowprops=dict(arrowstyle="-",
                                color="0",
                                patchB=None,
                                shrinkB=0),
              bbox=bbox_props, zorder=1, va="center")
    iti = 0
    for i, p in enumerate(wedges):

        ang = (p.theta2 - p.theta1)/2. + p.theta1
        y = np.sin(np.deg2rad(ang))
        x = np.cos(np.deg2rad(ang))
        horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
        connectionstyle = "angle,angleA=1,angleB={}".format(ang)
        kw["arrowprops"].update({"connectionstyle": connectionstyle})
        #kw['bbox']['fc']='#ffffe6'

        texts_line_store = []

        for ind,nme in enumerate([labels[i]]+labels_lips1[i]):
            if ind == 0:
                percent = sizes[i]/sizes.sum()*100
                txt = str(nme)+' '+ str(np.round(percent,2))+'\%' 
                frmt = {'color':colors[i], 'fontweight': 'bold', 'ha':'left', 'va':'bottom','fontsize':29}
                cmt_line3_lst = [of.TextArea(txt, textprops=dict(frmt))]

                texts_hbox3 = of.HPacker(children=cmt_line3_lst, pad=0, sep=0)

                texts_line_store.append(texts_hbox3)
            else:
                percent = np.array(plots[i][ind-1])/np.array(plots[i]).sum()*100
                txt = str(np.round(percent,2))+str(nme)
                frmt = {'color':colors_gender[iti], 'fontweight': 'bold', 'ha':'left', 'va':'bottom', 'fontsize':25}
                iti+=1
                cmt_line3_lst = [of.TextArea(txt, textprops=dict(frmt))]

                texts_hbox3 = of.HPacker(children=cmt_line3_lst, pad=0, sep=0)

                texts_line_store.append(texts_hbox3)

            texts_vbox = of.VPacker(children=texts_line_store, pad=2, sep=0)

            # Put the final box on the figure
            #annot2_bbox=dict(facecolor='yellow', boxstyle='round', edgecolor='0.5', alpha=1)
            #arrow2=dict(arrowstyle='-|>, head_width=0.3', linewidth=1, facecolor='black')

            annot2 = of.AnnotationBbox(texts_vbox, xy=(np.sign(x), y),xybox=(np.sign(x), y),
                                    xycoords='data', boxcoords=('data'),
                                    arrowprops=kw["arrowprops"], bboxprops=bbox_props)


            ax.add_artist(annot2)
            #s = ax.annotate(text, color= colors[i], xy=(x, y), xytext=(1.8*r*np.sign(x), 1.6*r*y),size = 20,
                       # horizontalalignment=horizontalalignment, **kw)

    #centre_circle = plt.Circle((0,0),1.24,color='white', fc='white',linewidth=2)
    #fig.gca().add_artist(centre_circle)
    plt.show()
    # save
    from io import BytesIO
    f = BytesIO()
    plt.savefig(f, format="svg")
# Out:
# \%  CE     78.901305
# \%  DAG    12.571796
# \%  TAG     8.526899
# dtype: float64
# \%  PC    66.205477
# \%  PE    21.038846
# \%  PG     0.000000
# \%  PS    12.755677
# dtype: float64
# Free cholesterol
# \%  Cer      2.647520
# \%  DHSM     0.939782
# \%  SM      96.412699
# dtype: float64
# \%  CE     35.470344
# \%  DAG    44.171941
# \%  TAG    20.357715
# dtype: float64
# \%  PC    58.411373
# \%  PE    33.244591
# \%  PG     0.688565
# \%  PS     7.655471
# dtype: float64
# Free cholesterol
# \%  Cer      3.590073
# \%  DHSM     0.749004
# \%  SM      95.660923
# dtype: float64
# \%  CE     14.309341
# \%  DAG    68.205388
# \%  TAG    17.485271
# dtype: float64
# \%  PC    59.765432
# \%  PE    28.702662
# \%  PG     2.468465
# \%  PS     9.063441
# dtype: float64
# Free cholesterol
# \%  Cer      3.798297
# \%  DHSM     1.505595
# \%  SM      94.696108
# dtype: float64
# \%  CE      1.115801
# \%  DAG    65.976186
# \%  TAG    32.908013
# dtype: float64
# \%  PC    66.442186
# \%  PE    24.791422
# \%  PG     3.767849
# \%  PS     4.998542
# dtype: float64
# Free cholesterol
# \%  Cer      3.875300
# \%  DHSM     2.740527
# \%  SM      93.384173
# dtype: float64

# %%
t2 = t.iloc[:,133:151]
import itertools as it
col_total = [list(g) for k, g in it.groupby(t2.columns, lambda x: 'total' in x) if k]
col_vals = [list(g) for k, g in it.groupby(t2.columns, lambda x: 'total' in x) if not k]

# %%
for i,x in enumerate(col_total):
    df = t2[x + col_vals[i]]
    fig, ax1  = plt.subplots(figsize=(8.8, 5.51))
    box1 = ax1.boxplot(df[x].values, positions=[0], labels = x)
    ax1.set_ylabel(x[0] + ' in umol')
    ax2 = ax1.twinx()
    box2 = ax2.boxplot(df[col_vals[i]].values,
                     positions=list(range(1,len(col_vals[i])+1)),
                     labels = col_vals[i])
    ax2.set_ylabel('% of ' + x[0])
